# %% [markdown]
# ### Date: 17 June 2020
# # Name: Arjun Kumar
# # Email: Karnarjun2000@gmail.com
# # -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Prerequisite For Running this Kernal----- Better Strength of Internet Connection

# %% [markdown]
# 1. Login to your Instagram Handle
#    1. Submit with sample username and password

# %% [markdown]
# #### Please Enter the Username in place of 'SAMPLE USERNAME' and Password in place of 'SAMPLE PASSWORD' for running this kernal

# %%
#importing library and class for webdriver and for explicte waiting
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait#for using explicite waiting
from selenium.webdriver.support import expected_conditions as EC# for locating certain element
from selenium.webdriver.common.by import By# for by which condition we want to locate

# %%
# executing a new chrome driver to open Instagram
driver=webdriver.Chrome(executable_path="/Users/karna/Desktop/chromedriver")
driver.maximize_window()
#driver opening website of Instagram
driver.get("https://www.instagram.com/")
# it is for explicite waiting for 10 sec, when ever waiting required We will use it 
wait=WebDriverWait(driver,10)
#locating the area where we can enter username
email1=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"_2hvTZ")))
#entering the usename
email1.send_keys("SAMPLE USERNAME")
#locating the area and sending the password
driver.find_element_by_name("password").send_keys("SAMPLE PASSWORD")
#now submiting the username and password
driver.find_element_by_class_name("sqdOP").submit()
#locating the popup-window
clickable=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"cmbtv")))
clickable.click()
#locating againg the popup_window
clickable=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"HoLwm")))
clickable.click()

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 2. Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”
#    1. Note : Make sure to avoid printing hashtags

# %%
#clicking on search bar of instagram
driver.find_element_by_class_name("pbgfb").click()
#typing "food" in search bar
driver.find_element_by_class_name("XTCLo").send_keys("food")
#locating all username who appered after typing 'food'
food_list=driver.find_elements_by_class_name("Ap253")
for i in food_list:
    #getting the username as str object
    a=i.text
    if('#' in a):#removing '#'
        a=a[1:]
    print((a))

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 3. Searching and Opening a profile using
#    1. Open profile of “So Delhi”

# %%
driver.get("https://www.instagram.com/")
#locating searchbar
driver.find_element_by_class_name("pbgfb").click()

driver.find_element_by_class_name("XTCLo").send_keys("So Delhi")
SoDelhi=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"Ap253")))
SoDelhi.click()

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 4. Follow/Unfollow given handle -
#    4.1 Open the Instagram Handle of “So Delhi”

# %%
driver.get("https://www.instagram.com/")
#locating searchbar
driver.find_element_by_class_name("pbgfb").click()

driver.find_element_by_class_name("XTCLo").send_keys("So Delhi")
SoDelhi=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"Ap253")))
SoDelhi.click()

# %% [markdown]
# 4. Follow/Unfollow given handle -
#    4.2 Start following it. Print a message if you are already following

# %%
try:
    #locating follow button
    follow=driver.find_element_by_class_name("jIbKX")
    follow.click()
    print("Now you are Follwing")
except:
    print("You are already Following")
# Out:
# You are already Following

# %% [markdown]
# 4. Follow/Unfollow given handle -
#    3. After following, unfollow the instagram handle. Print a message if you have already unfollowed.

# %%
try:
    #locating follow button
    driver.find_element_by_class_name("-fzfL").click()
    unfollow=driver.find_element_by_class_name("aOOlW")
    unfollow.click()
    print("Now you are UnFollowing")
except:
    print("You are already UnFollowing")
# Out:
# You are already UnFollowing

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 5. Like/Unlike posts
#    5.1 Liking the top 30 posts of the ‘dilsefoodie'. Print message if you have already liked it.

# %%
driver.get("https://www.instagram.com")
driver.find_element_by_class_name("pbgfb").click()
driver.find_element_by_class_name("XTCLo").send_keys("dilsefoodie")
from bs4 import BeautifulSoup
dilsefoodie=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"Ap253")))
dilsefoodie.click()
time.sleep(3)
post=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"eLAPa")))
post.click()


heart=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"fr66n")))
fill=str(heart.get_attribute("outerHTML"))
if(not "#ed4956" in fill):
    heart.click()

for i in range(29):
    driver.find_element_by_class_name("coreSpriteRightPaginationArrow").click()
    heart=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"fr66n")))
    fill=str(heart.get_attribute("outerHTML"))
    if("#ed4956" in fill):
        pass
    else:
        heart.click()
print("You have Liked first 30 posts of dilsefoodie")
driver.get("https://www.instagram.com/")
# Out:
# You have Liked first 30 posts of dilsefoodie

# %% [markdown]
# 5. Like/Unlike posts
#    5.2 Unliking the top 30 posts of the ‘dilsefoodie’. Print message if you have already unliked it.

# %%
import time
driver.get("https://www.instagram.com/")
driver.find_element_by_class_name("pbgfb").click()
driver.find_element_by_class_name("XTCLo").send_keys("dilsefoodie")
from bs4 import BeautifulSoup
dilsefoodie=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"Ap253")))
dilsefoodie.click()
time.sleep(3)
post=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"eLAPa")))
post.click()
heart=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"fr66n")))
fill=str(heart.get_attribute("outerHTML"))
if("#ed4956" in fill):
    heart.click()


for i in range(29):
    driver.find_element_by_class_name("coreSpriteRightPaginationArrow").click()
    heart=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"fr66n")))
    fill=str(heart.get_attribute("outerHTML"))
    if("#ed4956" in fill):
        heart.click()
print("You have Unliked first 30 posts of dilsefoodie")
driver.get("https://www.instagram.com/")
# Out:
# You have Unliked first 30 posts of dilsefoodie

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 6. Extract list of followers
#    1. Extract the usernames of the first 500 followers of ‘foodtalkindia’ and ‘sodelhi’.

# %%
 #6.1 Extracting the username of the first 500 followers of "foodtalkindia"

driver.get("https://www.instagram.com/")
driver.find_element_by_class_name("pbgfb").click()# finding search bar
driver.find_element_by_class_name("XTCLo").send_keys("foodtalkindia")# searching foodtalkindia in searchbar

foodtalkindia=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"Ap253")))
foodtalkindia.click()# clikcing on searched name appeared as foodtalkindia

follower=wait.until(EC.presence_of_element_located((By.XPATH,"//ul[@class='k9GMp ']//a")))
follower.click()# cliking on follower button

scr1=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"isgrP")))# now locating the pop window appeared in which followers name occured

driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)# scrolling the popup page
username_foodtalkindia=driver.find_elements_by_class_name("FPmhX")# creating the list of object of all username appearing on followers pop-up window
while(len(username_foodtalkindia)<=500):# same process goes on till finding the 500 object of username in followers popup page
    username_foodtalkindia=driver.find_elements_by_class_name("FPmhX")
    driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)
    
print("Followers of foddtalkindia : ")
print()

for i in range(500):
    username_foodtalkindia[i]=str(username_foodtalkindia[i].get_attribute("title"))# now extracting the username from username selenium object
    print(username_foodtalkindia[i])
    
driver.get("https://instagram.com/")
# Out:
# Followers of foddtalkindia :
#
# sanchita_isha
# sumit.niyolia
# xsworldconsultancy
# chef_japvir
# _cookindia
# hasan_chd_2020
# houseofawadh
# ranjita_tgw
# me_a_foodista
# mojtaba_pm.official
# sir_kaish_tik
# mrunalthakur_2020
# hey_dilli
# grabaspoon2020
# triptidimrilovers
# error_inn_life_
# raasoirani
# wildchillllife
# anusha.02
# rahmanialihusnain
# sprigsandcurryleaves
# rahulm183
# pushpendra_banna_5865
# venkat.8699
# muskann19
# snap.cook
# shakkr_india
# no_ud_dy_kh_an
# i_am_rahul_rt
# mitesh8221
# rajeev.moudgil
# heal.er.m
# minnion__love
# anatebet_bisnis
# lovely__1323_shree
# s_a_n_s_t_h_i_t
# dads_princes97
# shameemchamparani
# gustavomancero
# anoopneeraja
# _food_conso_spot
# hadjer_agg_
# vtdisinfectiontechnology
# m._r777
# btencoffeehandichai
# nirzariipandya
# _imainak_roy_
# shekhawatsarjeetsingh
# zfitness_trainer
# raju.17.rd
# sehrishkhan223
# rahul_akella.exe
# shamikagoelkk
# koted68
# thevaranasifoods
# anshmalhotra2190
# _graciously_beautiful
# sayliswnt122
# bhuvnesh_tomar
# raisha_wanderlustsoul
# piyush_and_preeti
# sanjanasanghiteam
# spices_catering
# azman5813
# chocolatetocheese
# arunav73
# ashutoshg_
# foodieharshi
# piyaghorpade2020
# pan_apron
# ___susi______
# wsym4211
# saket.zionunlimited
# mr_k_king.9624
# nilofer.e
# smruti8535
# devsfoodfiles
# deeksha_mehta_
# masihhussan
# rasoi_theflavourkitchen
# sandip932
# malphas_77
# muskan_virmani
# algeria_travel_natgeo
# borivalian
# foodie6518
# couples_vibes22
# payal280
# sibis_attil
# kavya_mahendar
# jasikamadaan
# nikhilportraitvision
# epicfoodiesworld
# moml.ifestyle6
# darklady135
# varunrnair_
# vandana3984
# weddings_planners_uttarakhand
# food.lifestyle242
# kashu1378
# rudranii
# the.manyavar
# taranjeetkaurmb
# _inner_peace._
# shivsingh1768
# ashwinee66
# hum_tum_or_food
# the_ghumantu_balak
# welcomtomykitchen
# _nixology_
# d.shuvra
# soso_17168
# iamshyamthakur
# thebakingsmiles
# archana2791
# klikbyme
# anytimemunch
# kapil_fitness_coach
# kangscookingcorner
# yous.sefeg
# shankarfoodie
# homie_chef
# harumi_in_the_kitchen
# c.dudeja
# vaishalirvispute
# dawntoduskstories
# umme_.ayman
# arnav29gupta
# chakhum.thekitchen
# pradeepmoonwalker
# roneelinsta
# sarvanichowdhury
# specialindianfood
# sanskari_ladkee
# nehasoni2029
# ishtax
# totbelly
# magical_rasoi
# foodi543
# pedonsonam
# srishtivasdev
# arjunhari
# su_nayana
# foodiememoriez
# rohitsaini1510
# sanjaypatil57
# delicious_foody_vibes
# saliniepari
# jiddus_cuisine
# bhaswati_nagchaudhuri
# fashionart1817
# yourcravingfood
# nitin.shitole_
# mysteriouskitchen___
# _craving_hut_
# oksharoz
# blissfulsoul_z
# thesliceofdreams2126
# global.pitara
# dilvarpreet_kang
# pilaniasonal
# bully_puppys_sale_
# kavish2005
# rtnkumarrajesh
# meghana_komatineni
# theruchakale
# must_c_me
# bain_marie_patisserie
# oleynik_vladimir
# piyusharya1.0
# 2a.ek
# that_foodie_sona
# shreyaa.jpg
# rashi_mehta
# homemade_indianfoods
# graffitiavenuesocial
# crispycrolly
# toctoquechefadomicile
# lazizz_22
# amlakeshomalenovin
# meghs_kitchen
# biryani.95
# my_mama_cooks
# nasemsaifi09
# uniqueforexandtravels
# anayachakravarti
# hiteshkumar42
# ashrafsayyad1234567890
# strategic_management_alliance
# yourbasiceatery
# dh_shreya
# thedocinmaking
# vasanvishnuvardhan
# ayanaajithan
# krishnaraj_mane
# lets_aarambh
# pandit_prashant1
# sarah_xx1111
# raikwar2213
# elitaaapaulaaa
# arrpitgoyal
# nazneen.a.kadar
# jaichitale
# musa_masoyi
# mister_dhruv
# mr_devil__boy
# oneindiafood
# __foodieme__
# divya_dhanapal
# singhmona91
# nasirajwaa
# uzer_khan1503
# foodspecial27
# _the_kitchen_jungle
# explore_world_universe
# arpitaa22
# drtinkusinha
# _yummiya_
# secret_flavours_delight
# jagdeepsinghbilkhu
# houseofradbakes
# blogcorporat
# choreographer_varun_
# only_officials_account
# lifeoutofthebox2020
# shail_373
# nagarajutkoor
# _tastytreat_
# crazzymissey
# hidayat.kings
# jaanifoodcourt
# kapda_kothi
# pr__marketing_
# eatindianstyle
# food_stuffdairy
# gurudev_krishnadas_shastriji_3
# vipwebtech
# jk_maheta786
# mr._mrs._aujla
# yashaswinip2502
# dogricuisine
# gapparoff9647
# shuchishreshtha
# _vacationly_
# chefsrini27
# ashokanandmbbs
# kalakaari_kanya
# vineethrvnair
# bliss_jenny_
# love_baisware
# dr._aayushi_n._saraiya
# _akansha_khatri_
# ms_anna425
# exotic_nuts_and_spices
# __change__iss__constant__
# wake_.and_.bite
# bravo_.20
# mohamadghalebi1234
# surbhivarma.30
# crkz_sam
# bulani_sarthak
# rabailmotihar
# o1803ooo
# lockd_ownartist
# bpchmt
# its._sanjay_
# laziz_caterers_1996
# aps2k17
# cooking_with_amina_muhammad
# thehungryhindustani
# r0hitraj1007
# _official_vishu_07
# nikhilmathur20
# d_r_e_a_m_er7
# planetherbssciencesindia
# menonanita1
# _____black.hearts_____
# joe.vargaz
# syeda4947
# abhishek.marwaha
# recipesfromhemaskitchen
# astha1805
# __for.theloveof.food__
# kitchen_.kreations
# sanyamalikk
# scientifically.speaking
# chefandreamura
# roshnii_chawla
# rezashakeri08
# sunil11100
# willowsbakencakes
# neelamgabra
# dishi_2k17
# nooreraj007
# bhatleabhi
# poojah1808
# beatka0208
# foodn_ess
# fooditales
# thinkgood1212
# foodysingh3
# simran_pahwa05
# anjumnaaz08
# rahul_jadaun__
# doodling.life
# foodbuff5
# poonam_bafna
# _travel_wander
# jai_shankar_vishwakarma
# petesky1111
# foodie_ishq_love_food
# flavoursa_dspices
# madhu.sahoo1
# veg_ezy
# mona.bawani
# foto_addictive
# im_julkap
# bakedinthought
# secret_chef25
# pajamaa.diaries
# tejashree_recipes
# ushamishra5473
# pratibhanaruka08
# shalini.khandelwal.96995
# anjalijain1707
# chef_tyagi_17
# smones
# ektatul
# homekitchen_for_foodie
# niki.ta4171
# anandipickle
# vishumoni
# mommytimesblog
# sharmxnx
# arunadatta333
# shivanig25
# nagpur_ig
# karthigamagudeeswaran
# foodwai
# feastologist
# foodie.goodie50
# tates.bakes_
# suma_naina_
# manenikhil24
# agrawal.ankita26
# tasmiyashaikh1234
# alkama_azam
# cookwithanaspiringvegan
# __.blue._berry__
# zoyasaraarora
# ankit_singh333
# aman.narang9
# food_cravings66
# agrawalsahab_
# moses_ranapanga
# nitishk1504
# haleema6863
# imalive_sheoran
# grannys.gurgaon
# your_food_fantasy
# shruti_nayyar_chaddha
# karmare_life45
# being_sensational
# desifoody
# madhus_cooking_corner
# stutisharma20
# gouri0073
# foodwalahai
# afrinkhan6790
# s_h_a_h_i_d__p_o_p
# yummyworld_
# foodsthaa
# lehsun_mirchai
# ceaseless_steps
# m.o.n.a_sh12
# bhukadindia
# an.shu8396
# me_ankitnagpal
# swamikitch
# ggoatalicious
# littlesweetlab
# shriyanarayanan
# the_roz.ted_beans
# yichen_0077
# morselofdeliciousness
# mr_kp__13
# bhawnagulatimakeupartist
# craversbooty
# iraullyira
# dhirajdeora65
# refectionsthejuicebar
# pritinchachadphotography
# saavi1602
# niku.nikita.sharma
# _khaadya_padarth
# shraddha_kokane_7011
# __ayushi__sharma__
# nitisha_adhikari_01
# vineet_udaykumar4
# _desired_destination_
# localfoods.official
# servings_of_singhania
# mr_fier_boy
# ashadmalik_01
# khana_ka_ghosla
# siddharthsaini99
# dining_like_a_pro
# the.lemonbowl
# talukdar.anjana
# sumanyadav6745
# thecinemstars2
# fryyo_official
# chandni_rohatgi
# foodchronos
# rajasthanrestaurantkadodara
# i_jaikiran
# r3rising
# foodsourcetelevision
# manukondarajesh
# pearl_in_shell_
# vanibhatia1
# sinfultreats2013
# ____goodfood___
# cocoa_choco_
# meettandeatt
# renuka.hinduja
# money_machine47
# parulgoel58
# sidvarundigital
# riderbaba_
# aayushi.jajodia
# pavitrakaur
# veganvivek
# chefsudhanshugupta
# thesweetsky_
# alkaarora0812
# vikramprajapatd
# creamandcakes03
# kishu_garud
# ushatirkey13
# cocunut27
# nazis7305
# saifsanade
# thebhutiagirl
# khanrafik07
# freebird_pratik123
# shadabmalik132
# abhi_vaishnav25
# wilburlarryjoseph1
# virat.chouhan13
# mi_soulkadi
# theurbanfarm.co
# art.amour2020
# quaransweetsph
# the_tejpal_janwa
# aurora_chinu
# aslibharat_
# _____danish.zehen_____
# ahmadrizvi123
# foodsnbuzz
# the_t8ste_buds
# lx.mustaqeem.09
# thenameismaniesh
# saksham.7529
# divya.jain.921
# immortalreflection123
# lakis.family.restaurant
# aspicejourney
# dockapilsharma
# ___kavya___25
# cookingbyhand
# riyafarmania92
# pooja.bakraniya
# hrithik.ros.han
# akib4422
# __ansh_gupta
# shrutkirti04
# memon3253
# kashishgupta404
# thekitchen_by_snr
# desi_or_videshi_recipes
# nitisharma156
# vidhi7042
# 63.95654510
# aryan.aroraaa
# fryandtadka
# tamimsultana
# divyassaini
# whattawaffle
# akshaypartapss
# _highflames_foody_page
# empressappetite
# amritsari.naan
# naman_tohra
# saffronnolive
# annapurna__kitchen
# itz_javed_khan0607
# tapan1515
# shaanvasavada
# ciy_cookit_yourself

# %%
# 6.1 Extracting the username of the first 500 followers of "sodelhi"

driver.get("https://www.instagram.com/")
driver.find_element_by_class_name("pbgfb").click()# finding search bar
driver.find_element_by_class_name("XTCLo").send_keys("sodelhi")# searching sodelhi in searchbar

sodelhi=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"Ap253")))
sodelhi.click()# clikcing on searched name appeared as sodelhi

follower=wait.until(EC.presence_of_element_located((By.XPATH,"//ul[@class='k9GMp ']//a")))
follower.click()# cliking on follower button

scr1=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"isgrP")))# now locating the pop window appeared in which followers name occured

driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)# scrolling the popup page
username_sodelhi=driver.find_elements_by_class_name("FPmhX")# creating the list of object of all username appearing on followers pop-up window
while(len(username_sodelhi)<=500):# same process goes on till finding the 500 object of username in followers popup page
    username_sodelhi=driver.find_elements_by_class_name("FPmhX")
    driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)
    
print("Followers of sodelhi : ")
print()

for i in range(500):
    username_sodelhi[i]=str(username_sodelhi[i].get_attribute("title"))# now extracting the username from username selenium object
    print(username_sodelhi[i])

driver.get("https://instagram.com/")
# Out:
# Followers of sodelhi :
#
# _hassen03
# chirag3697
# ribin_photography
# patnaikamrita
# archit1791
# sachdia427
# aditi.goyal
# rohit_vij18
# thakuradityaanand
# narwal673
# nishhspaam
# be_own01
# drrajain
# prathamj09
# kavyaa_agrawal
# pulkit_tyagi_
# _riya.24
# saif_1337
# rakeshji448
# dreamsnlies
# faziya96
# aahat_1khanna
# himanshigarg007
# rachit256
# jain.prateeek
# asraf258
# iam_sagittarius_girl
# ritikaverma_5
# rupammalik
# _pranvi_sharma_
# am.bbyg
# trishatalwar
# ram.pratap.singh
# shee_veee
# wadhwaaditya04
# dhwani.sarodia
# mishee2001
# khushg.newlyf
# kiratalreja
# ishita.agrawal__
# narrator_of_your_story
# akanksha.0710
# pradeeptomar305
# iam__hrk09
# thenameiz_mahesh
# abhi_adven
# _me_pragya
# kzr_sk
# sankalpbharadwaj
# vibhory4
# vish__red
# artress6
# chandni_.goyal
# khansam.09
# triptidimrilovers
# meenakshisonia
# tbhalla97
# ayushibhagat236
# singhgourav93
# _kritika_sharma_
# megha.sood09
# mehak.srk
# raasoirani
# agrim_13
# singh.shifali27
# _shivani_2_3
# avantika15singh
# eventsforeveryone
# manyasethi_
# amrit.kaur20
# lifeof_nitin
# prabhsahib_gill
# cute.boy7958
# apranshu
# pinchofcraving_
# ann_mariya_222
# ramindersngh
# sona14000
# be_saraswat
# kanishq_basoya_dellhii0001
# inder4500
# tanushri_joshi17
# shivangiii_agarwal
# rish_ag02
# shanky1893
# pronoy_neogi
# _divyakohli_18
# iam_ankurgupta
# hypestudio.in
# s_shubham_9
# hakmarshall1995
# oishee2202
# ankita21_singh
# moml.ifestyle6
# pooh.priv11
# saurabh._.s
# _amandeepnain_
# yourmenumaster
# moscot_93
# halimamehvish
# __smritisingh_
# free.soul.rider
# artitiwari388
# sfighte357u
# umarfarooque050
# muskan_agg98
# sandip.dhengale.73
# 2330.jo
# foodiejudo
# chehak01
# ramansaini13
# thakurkeshavbhati
# highonpastaindia
# varunsagar750
# balaramkarna
# veritytales
# hope174874
# selva_laxmi
# gaurimittal
# sexyhaway
# milankumarkamat
# btencoffeehandichai
# shardul_0701
# reza.reihani.1384
# niyuktipasricha
# mittal__dhruv
# ashimakohli18
# _kritika.kaushik_
# simbabhalero
# ishan_jain001
# jaavedaana
# trend_captain
# guptavaibhav2311
# suma_n231
# cake_rider
# aennastylist
# colourful_sunset
# madihahahahahahaha
# nishitarathi
# ansari_786_ji
# chohanmshahroz
# achinagarwal_12
# neelamgahlyan
# bhutani.dhruv
# coca_cola_official_india.075
# ashish_sachan
# adarsh_sharma0001
# kirrrttiii
# aa.roo.shee
# adarsh.kushwaha.50
# priyakalra06
# virat.india
# rumneat
# sparsh_goyal_2000
# printf_food_plz_
# uniq.ueprojects
# junejadilpreet
# gokulsv
# kapoor.prerna
# rahul_suneja
# viditganpi
# alex_gupta_
# nandaanubhav
# monamishraa
# veer76918
# prashi_khurana
# iamshubham7393
# _sonal_b
# naziyakhan200
# sanam_j56
# atishaybaid
# _akritiarora
# kanchan.manjrekar.50
# swarajgoswami
# juneja_shefali_23
# tulicamittall
# thefoodiesista
# vishesh_jain_20
# shvm2109
# prettymessysoul
# sumi_1938
# karanbabbar99
# roshnikhemka
# estheticcxx
# sanskriti__agrawal
# su.rajkumar302
# sonu_sharma655
# jayant___13
# dggupta29
# gardensajao
# nidss39
# rishabh.3011
# _eternal_secrets_
# adiiiteeee
# ashutoshg_
# _shh.hhb
# raunaq.singh_
# archanamishra9250
# arshanm13
# pro_salil
# anshikamishra451
# shruti_6209
# sanyamjain65
# yatin9045
# adityakumar7352
# kaur.pretty
# hanika.singh
# roamingbeastt
# vidikalakhwani
# sgupta1293
# its_roman_reign_s
# iammb3
# _abhishe_k
# deependar373
# shakkr_india
# traptigoyal
# chanmeet.sethi
# pal.anoushka
# dabistaneurdu_urduschool
# sunidhijain26
# ayushgar
# _therealmishraji
# abdeali_bhanpura53
# womens_zone0
# punyyaa_a
# prachibansal3534
# nilofer.e
# vibe_with_jac
# _shreyash19
# sonineha89
# neelankbhattar
# sgtravel_gram
# 1995.kritika
# piyushsingh5007
# nishaant_
# _surbhi_singhal
# _pranjal.yadav_
# nayna.garg
# avani.paliwal
# mansi_chawla_lorai
# priya.priya28
# acolortale
# fantasy_parade07
# solacedwithtea
# geetika_bhan
# rishu1410
# rahul_vishnoi
# sameercherwoo
# 1212jayesh
# liaagnes_089
# indraneelbhandari
# divyam09srivastava
# wesandpaper
# rohitgupta25_
# priyanka_sharma9813
# the_peach_delirium
# minian_city
# 17aruj_g
# b1lal__007
# malphas_77
# ankita_johry
# juhirana12
# nobles0ul
# 12neha_
# notyourbestfrnd
# komalkhatri_14
# sneha9deshmukh
# somendu.scorpion
# bhawana.tiwari
# karthika_195
# sacred_shiit
# watts.on_das_pallav
# shubham_jain1594
# ankitanarsey
# delhi.shooters
# shivangitaneja6
# laura7closet
# bhukked_world
# jatin_singla9
# prithamukherjee5314
# imsiddhimehta
# frontier_bakery
# tanishkababber32
# nikkkhil_gupta
# toniqaccessories
# sharma.anusheel
# jitesh_goel.13
# chaos_in_her_veins
# xra169
# mrityunjoykumar
# bikramjeetsinghh
# yaminimathur66
# gauravsharma92
# kmaheshwari_
# karan_vermani19
# cheekibreeki999
# ekta.sharma0168
# yash_phor
# alinaqisherazi
# aryan_jindal_
# amitsinghpvt
# divinedelhi
# dipika2426
# heenakshig16
# gaurav_upadhyay___
# moldireddy_vinay
# meme24x7_2020
# sumit.asr
# lalit.k.singh
# maanugrwl0
# jazzkaur2516
# niharikasinghal
# anshul_aggarwal
# khushbooyadav0
# sangeetarawat472
# sayan__paul
# _harshitabhatia
# anmolrao.0105
# ovaisakhtar8
# amangoyal0302
# aashnabansal7
# agarwal.sahil
# varunrnair_
# manyagupta_09
# anoopkumar1244
# steffibhatt95
# tanyakhatri100
# shrsti
# aditidubey_2611
# bishtnatasha43
# no_one1111._
# kunalmnchnda
# the_krishna_gupta
# niharika_sahni
# travel_living_wanderlust
# i_am_rashisharma
# smarty_pandeya001
# _mahi__1017_
# vikash_singh_007
# cooking_l0unge
# wakeupmohit
# sanchit1640
# kunalkalita05
# _battsyyy
# jainsurbhi18
# _pareek_gippy
# _antrasaxena
# _shruti._sharma
# ankitpathak101
# amzad_azad1626
# grumble.eat.grumble
# _miss_shaheen
# iamankiteshsingh
# krish.__k
# ankitajainnn
# bhavnalove357
# sourav_k777
# sagar.anand.sharma
# inimitablekunal
# kirti._.gill
# thefoodiestaaz
# seth.saksham
# rishika.bera
# anant.01
# rollin_since96
# himangini_98
# tathagatghosh
# rohit_varma_
# nehabathla18
# foodie__nadiad
# tdivyanshu99
# annapitanga
# raunakgupta_17
# bhawna_9595
# zehain_._khan
# discoveringpondicherry
# the_winked_eyes
# lensoverated
# chhavigoel6
# pria_jhaa
# saurabhcaptures
# roohaniyat_allweate
# shakti_shekhar
# shakshi_31
# cool_rohitgarg
# saiyam221
# shivanigulati97
# aakankshab
# vinit.kush
# aribarib56
# punitkhanna17
# kritikarashi
# samanyu_srivastava
# kriti.kansal
# jahnavii_28
# theshowfactory
# rajaryan_x
# shivam.sharma997
# shwetasharma24257
# vasurajagarwal
# sidhdhisingh
# tilakmanan
# garg_gaurav97
# prabhat21_
# gift_them_best
# dhruvkaistha
# mysterious_soul19
# itskaustubhraj
# king_ashteon
# vipul2067
# sabinkumar_69
# zaiqa_delhi6
# palakg13
# lalupasna
# ashish.o9
# 0_uday_0
# ravithaakur
# lyfe_uncertainty
# gaganbeniwal1812
# srish.97
# shr.oyo
# dhwanibhatt27
# _prakharpathak
# ashwaryag
# abhishek_agg1
# vastvik_anand_
# sagar0430
# shrxyyx
# nayyar.mayank
# iisha.singh
# khalid__naseem
# trijyasinghal
# bhavanabansal_15
# priyankaprajapat
# rohana_gunnu
# ayushishukla23
# nswtravelogue
# _janviiiii
# ithinkpinkfloyd
# samay9591
# na37039_neha
# salikkhan52
# gladium08
# thalassooophile
# jatinshad
# smilobunny
# indya.bungy
# prakhar.01
# miggy_muse
# bby.aruna
# rahul_a29
# bharat_ofc
# shubhra611
# lizamakeoversandacademy
# gauribansal02
# prachi_make_over
# goel_aman_66
# thesankalpagrawal
# anshuman_.18
# srishti2695
# ekta_bansal_
# jatin___v
# theperspicaciouscompanion
# sanchitmittal18
# padge_the_dog_
# manojnandaa
# manikagarg96
# aditya.m5
# _the_crazy_prodigy_
# _ananyagoyal
# _sheena.bhatia_
# piyush_tyagi16
# the_sahilkhan
# jha_kanupriya
# kanishkanagpal
# sakshijain_1
# varsha_ag11
# rimjhim9998
# akanchha_gupta
# ashichauhan4
# imayur26
# aarenashadowfightfallout
# aruna_agarwal0911
# kenzieloo14
# vkt_pvt
# anaghamalik
# harshitkag2010
# sans.kritifashionhouse
# sonia_purswani
# arey_govind
# no.one.qoutes
# harshita3323
# m_u_s_k_a_n_23
# growandglowtogether
# iam_dhruvrastogi
# tejsai25
# ayaan_saifi_143
# led_zeppelin1712
# superscrumptious
# manvi_chaudhary

# %% [markdown]
# 6. Extract list of followers
#    6.2 Now print all the followers of “foodtalkindia” that you are following but those who don’t follow you.
#
#
# ##### For solving this question, first I will find own followers(as own_followers), then finding the whom I following(own_following), then
# ##### will find the foodtalkindia's followers(username_foodtalkindia) whom I am following , but they are not following me, by just perfoming set operation of
# ##### ( own_following & username_foodtalkindia) - own_followers

# %%
#6.2 getting the username of my account followers, ie whose username and password is used for running this kernal

driver.get("https://www.instagram.com/")

driver.find_element_by_class_name("SKguc").click()# cliking on own username that is appering on instagram

follower=wait.until(EC.presence_of_element_located((By.XPATH,"//ul[@class='k9GMp ']//a")))# locating the follower button
follower.click()# clicking on follower button

follower_number=int(follower.text.split()[0])# finding the number of own followers

scr1=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"isgrP")))# locating the pop-up window in which followers usernames appeared
driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)# scrolling the pop-up-window
own_followers=driver.find_elements_by_class_name("FPmhX")# creating the list of selenium object of all usernames
while(len(own_followers)!=follower_number):# process continue till to find all followers
    own_followers=driver.find_elements_by_class_name("FPmhX")
    driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)

for j in range(len(own_followers)):
    own_followers[j]=str(own_followers[j].get_attribute("title"))# extracting the username from usename selenium object
    print(own_followers[j])
    
driver.get("https://www.instagram.com/")
# Out:
# neeraj_billa
# apni_.rasoi
# ravi_gupta271992
# arora.nayan999
# garg_sahab_1.0
# campus_ceos
# 5hantanu_5ingh
# rajkumarprasad63
# garhwal_praveen
# lokesh.arora_
# mohitraj5156
# we_edmad
# ajinkyasinha.08
# rohitkashyap_1411
# pathak943
# programmer_world143
# abhi_now_007
# g4bsetup
# vibhorthukral
# abhaykumar001007
# rajeshkashyap593
# a.s.h.u.t.o.s.h.2
# chint_ugupta
# kaushal_kumar_sunny
# ravigupta9684
# govindasinghkunwar
# ampupant
# dewal_hitt_u
# purushotam9852
# satyamrathour03
# varunmenon24
# aashishrao432
# alok__yadav9
# ankugupta6887
# raviguptaamba
# tanishq.ameta01
# diwakar_7668
# rachit_keshari_
# lalitkr07
# nikhilkumar3823
# karan632_
# 510dharth_shekhar
# lakshayrana1299
# amman_badsha
# _avi.75
# rajakumar7184
# riaelytha
# dheeraj_mandal_6200
# ck824125
# princegupta43518
# devenjain.25

# %%
#getting the username whom account holder is following 
driver.get("https://www.instagram.com/")

driver.find_element_by_class_name("SKguc").click()# clicking on username of account holder

following=wait.until(EC.presence_of_all_elements_located((By.XPATH,"//ul[@class='k9GMp ']//a")))# locating the following button
following_number=int(following[1].text.split()[0])# finding the number of following
following[1].click() # clicking on following button

scr1=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"isgrP")))# locating the pop-up window on which following username appears
driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)# scrolling the popup winodw to get all username appearing on it
own_following=driver.find_elements_by_class_name("FPmhX")# creating the selenium object of all username
while(len(own_following)!=following_number):# process it contiue till we find all followings username
    own_following=driver.find_elements_by_class_name("FPmhX")
    driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)
    
for j in range(len(own_following)):
    own_following[j]=str(own_following[j].get_attribute("title"))# extracting all the username from usename selenium username object
    print(own_following[j])
    
driver.get("https://www.instagram.com/")
# Out:
# snap.cook
# apni_.rasoi
# cafeseason67
# officesonusharma
# indiancricketteam
# thestockmarketindia
# successmantra.1
# motivationalpark
# motivation_line_
# chanakyamotivation
# humjeetenge
# ravigupta9684
# saurabhtd
# 5ketch_and_capture
# arora.nayan999
# garhwal_praveen
# rajkumarprasad63
# jaskamboj405
# d.o_djent
# mohitraj5156
# saurav.prakash.gupta
# ajinkyasinha.08
# deepakkumarg770
# aashraya_isha_helpers
# startupbusiness4u
# abhi_now_007
# pathak943
# startupdaily_
# entrepreneur_startup_stories
# startup_maharashtra
# campus_ceos
# startupsuccessstories.in
# startuptrev
# startup_talky
# startupstudioonline
# thestartuptalks
# startuplan.es
# unfiltered.indian
# startup_founderz
# startup.mp4
# startupselfie_official
# startup_india
# theozon.in
# startup_crackle
# startup_jalsa
# yourincomewolf
# startupnews.fyi
# startup.pedia
# indianstartupnews
# startupstoriesofficial
# startup_360
# coding.ninjas
# the_hindu
# codingblocks
# ekkadamsafaltakiorrgk
# natgeo
# datascienceinfo
# sadhguru
# vivek_bindra
# setup_tech9
# peoplewhocode
# ideadevelopers
# jagdishcodes
# codinginterviewcoach
# programmer_funstagram
# code_boom
# the_unity_creaters
# electronic_brain
# hackerscon
# proud_programmers
# codinganddecoding
# nerds_coding
# creativewebdeveloper
# code_student
# javascript.js
# codeamy
# tutorialsguru
# dev.space
# for_nerds_in_programming
# droidrax
# developers_team
# high_programmer
# programmerplus
# kickasscoders
# codinglife_ig
# programmer.lifestyle
# officialhackerinc
# thecybersecurityhub
# computer_science_engineers
# thehardsecurity
# geekboy
# codiosity
# teenprogrammer
# computersciencelife
# geeksport_
# webprogramist
# programmingofficial
# codermtn
# programmer.me
# programer.life
# _codehub_
# pure.python
# python.hub
# py_coder_
# i_know_python
# python_scripts
# amazing.python
# amazing_python3
# python.learning
# python.coder_
# codechef
# suprememusic__
# dailycodingquestion
# vibhorthukral
# _ashiq4_
# abhaykumar001007
# chetchat101
# rajeshkashyap593
# govindasinghkunwar
# dewal_hitt_u
# yash__mittal_
# geeks_for_geeks
# i_am_an_nitian
# jeetfix
# ankugupta6887
# alok__yadav9
# machine_learning_info
# aayushjalotra
# unwinding_saga
# varunmenon24
# 5hantanu_5ingh
# tanishq.ameta01
# aashishrao432
# dreamacchieverjatin
# shivamgarg1106
# sahilgupta2209
# suman_babuuu
# govirusgo
# jatinbansal_12
# kaushal_kumar_sunny
# purushotam9852
# garg_sahab_1.0
# be_doozy
# _shurui_
# schoolslife0
# johncmaxwell
# alexmortonmindset
# thelesbrown
# easyfuturebiznet
# kdpdinesh44
# john_lee_official
# lalitkr07
# reliancejio
# nikhilkumar3823
# truly_divyam
# karan_prasad_gupta
# ampupant
# rohitkashyap_1411
# siddharth.codes
# paytm
# a.s.h.u.t.o.s.h.2
# neeraj_billa
# diwakar_7668
# kunner_12
# 510dharth_shekhar
# vella_admi
# princegupta43518
# karan632_
# rachit_keshari_
# lakshayrana1299
# lokesh.arora_
# thepsycho_maniac
# ravi_gupta271992
# _avi.75
# devenjain.25

# %%
username_foodtalkindia=set(username_foodtalkindia)
own_followers=set(own_followers)# converting own_followeres list to set
own_following=set(own_following)# converging own_following list to set

# %%
print((own_following & username_foodtalkindia)-own_followers)# here performing set opeation of intersection(&) and difference(-) for obtaining desired result
# Out:
# {'snap.cook'}

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 7. Check the story of ‘coding.ninjas’. Consider the following Scenarios and print error messages accordingly -
#    1. If You have already seen the story.
#    2. Or The user has no story.
#    3. Or View the story if not yet seen.

# %%
import time
driver.get("https://www.instagram.com/")
driver.find_element_by_class_name("pbgfb").click()# locating search bar
driver.find_element_by_class_name("XTCLo").send_keys("coding.ninjas")# searching coding.ninjas in search bar

coding=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"Ap253")))
coding.click()# clicking on searched coding.ninjas
time.sleep(3)

try:
    status=driver.find_element_by_class_name("h5uC0")#locating status circle if status is presence else give error sending action to exception
    view=driver.find_element_by_class_name("CfWVH")# locating status button 
    if(view.get_attribute("height")=='131'):# when if status is seen , it's circle height has 131
        print("You have already seen the Story of this account")
    else:
        print("Story is being seen")
        view.click()
except:
    print("This account has no Story")

driver.get("https://www.instagram.com/")
# Out:
# This account has no Story

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------
